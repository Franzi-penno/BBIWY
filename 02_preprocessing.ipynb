# %%
from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
from text_magic.functions import pipeline

# %%
with open(file="quotes/quote_1_0.txt", mode="r") as file:
    text = file.read()

# %%
pipeline(text)
# Out:
# 'the world as we have created it is a process of our thinking it cannot be changed without changing our thinking'

# %% [markdown]
# Nebenschauplatz

# %%
from text_magic.functions import pipeline

# %%
text = "Hallo Welt wie geht es dir?"
pipeline(text, x=12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 text = "Hallo Welt wie geht es dir?"
# ----> 2 pipeline(text, x=12)
#
# TypeError: pipeline() got an unexpected keyword argument 'x'
