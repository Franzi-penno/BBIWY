# %%
from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from text_magic.functions import pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 from nltk.corpus import stopwords
#       3 from nltk.stem import PorterStemmer
# ----> 5 from text_magic.functions import pipeline
#
# File c:\Dokumente\data science\github rep\BBIWY\text_magic\__init__.py:1
# ----> 1 from functions import pipeline
#
# ModuleNotFoundError: No module named 'functions'

# %%
with open(file="quotes/quote_1_0.txt", mode="r") as file:
    text = file.read()

# %%
from string import punctuation

PUNCTUATIONS = punctuation + "“”‘’—"

# %%
text
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
def clean_to_lower(text:str) -> str:
    
   return text.lower()

def clean_punctuation(text:str) -> str:

    output_string = ""
    for character in text:
        if character not in PUNCTUATIONS:
            output_string += character
    return output_string

def clean_strip(text:str) -> str:
    for _ in range(10):
        text = text.replace("  "," ")
    return text.strip()

def pipeline(text:str) -> str:
    text = clean_to_lower(text)
    text = clean_punctuation(text)
    text = clean_strip(text)
    return text

# %%
pipeline(text)
# Out:
# 'the world as we have created it is a process of our thinking it cannot be changed without changing our thinking'
